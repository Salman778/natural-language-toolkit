# %%
import matplotlib.pyplot as plt
from nltk import FreqDist, word_tokenize

# %%
str_orignal = "A paragraph is a self-contained unit Of discourse in writing dealing with a particular point or idea. A paragraph consists of one or more sentences. Though not required by the syntax of any language, paragraphs are usually an expected part of formal writing, used to organize longer prose."

# %%
str_lower = str_orignal.lower()
str2_orignal = word_tokenize(str_orignal)
str2_lower = word_tokenize(str_lower)

# %%
str3_orignal = FreqDist(str2_orignal)
str3_lower = FreqDist(str2_lower)

# %%
str3_orignal.plot(30,cumulative=False)
str3_lower.plot(30,cumulative=False)
plt.show()

# %%
str3
# Out:
# FreqDist({'.': 3, 'of': 3, 'A': 2, 'paragraph': 2, 'a': 2, 'writing': 2, 'or': 2, ',': 2, 'is': 1, 'self-contained': 1, ...})

# %%
i = 0
for word in str3_orignal:
    i += str3_orignal[word]
#     print(word, str3_orignal[word])
print(len(str3_orignal), i)
# Out:
# 43 53

# %%
c = 0
for word in str3_lower:
    c += str3_lower[word]
    print(word, str3_lower[word])
print(len(str3_lower), i)
# Out:
# 41 53
